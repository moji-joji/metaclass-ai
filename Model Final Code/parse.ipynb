# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
from scipy.stats import mode
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.svm import SVC
from sklearn.metrics import f1_score

# %% [markdown]
# ## Data pre-processing

# %%
# List of response and time file paths
response_files = ['responseFile_1.csv', 'responseFile_3.csv', 'responseFile_4.csv', 'responseFile_5.csv', 'responseFile_6.csv', 'responseFile_7.csv']
time_files = ['timeFile_1.csv', 'timeFile_3.csv', 'timeFile_4.csv', 'timeFile_5.csv', 'timeFile_6.csv', 'timeFile_7.csv']

# Initialize DataFrames to hold the merged data
merged_response = pd.DataFrame()
merged_time = pd.DataFrame()
end_time = 0  # Initialize the end time

# Iterate through response and time files
for response_file, time_file in zip(response_files, time_files):
    # Load response and time DataFrames
    response_df = pd.read_csv(f"data/{response_file}")
    time_df = pd.read_csv(f"data/{time_file}")
    
    # for angles, center them at 180
    # (180 + pitch) % 360
    response_df[' Pitch'] =  round(((response_df[' Pitch'] + 180) % 360 ), 2)
    response_df[' Roll'] = round(((response_df[' Roll'] + 180) % 360),2)
    response_df[' Yaw'] = round(((response_df[' Yaw'] + 180) % 360),2) 
    
    time_df[' Pitch'] = round(((time_df[' Pitch'] + 180) % 360 ),2)
    time_df[' Roll'] = round(((time_df[' Roll'] + 180) % 360),2)
    time_df[' Yaw'] = round(((time_df[' Yaw'] + 180) % 360),2) 

    # Shift time values in time_df
    time_df['Elapsed Time (ms)'] += end_time

    # Update the start time for response_df
    response_df['Elapsed Time (ms)'] += end_time

    # Concatenate response and time DataFrames
    merged_response = pd.concat([merged_response, response_df], ignore_index=True)
    merged_time = pd.concat([merged_time, time_df], ignore_index=True)

    # Update the end time
    end_time = time_df['Elapsed Time (ms)'].max()

# Save merged response and time DataFrames to new CSV files
merged_response.to_csv('merged_response.csv', index=False)
merged_time.to_csv('merged_time.csv', index=False)

# %%
# List of response and time file paths
response_files = ['responseFile_1.csv', 'responseFile_2.csv', 'responseFile_3.csv', 'responseFile_4.csv', 'responseFile_5.csv', 'responseFile_6.csv', 'responseFile_7.csv']
time_files = ['timeFile_1.csv', 'timeFile_2.csv', 'timeFile_3.csv', 'timeFile_4.csv', 'timeFile_5.csv', 'timeFile_6.csv', 'timeFile_7.csv']

# Initialize DataFrames to hold the merged data
merged_response = pd.DataFrame()
merged_time = pd.DataFrame()
end_time = 0  # Initialize the end time

# Iterate through response and time files
for response_file, time_file in zip(response_files, time_files):
    # Load response and time DataFrames
    response_df = pd.read_csv('./data/' + response_file)
    time_df = pd.read_csv('./data/' + time_file)

    # for angles, center them at 180
    response_df[' Pitch'] = round(((response_df[' Pitch'] + 180) % 360), 2)
    response_df[' Roll'] = round(((response_df[' Roll'] + 180) % 360), 2)

    # Update time_df and remove old ' Pitch' and ' Roll' columns
    time_df['Pitch'] = round(((time_df[' Pitch'] + 180) % 360), 2)
    time_df['Roll'] = round(((time_df[' Roll'] + 180) % 360), 2)
    time_df.drop(columns=[' Pitch', ' Roll'], inplace=True)  # Drop the original columns

    # Shift time values in time_df
    time_df['Elapsed Time (ms)'] += end_time

    # Update the start time for response_df
    response_df['Elapsed Time (ms)'] += end_time

    # Concatenate response and time DataFrames
    merged_response = pd.concat([merged_response, response_df], ignore_index=True)
    merged_time = pd.concat([merged_time, time_df], ignore_index=True)

    # Update the end time
    end_time = time_df['Elapsed Time (ms)'].max()

# Save merged response and time DataFrames to new CSV files using float_format to ensure 2 decimal places
merged_response.to_csv('./data/processed/merged_response.csv', index=False, float_format='%.2f')
merged_time.to_csv('./data/processed/merged_time.csv', index=False, float_format='%.2f')

# %%
# Read the response_csv and time_csv into DataFrames
# response_df = pd.read_csv('merged_response.csv')
# time_df = pd.read_csv('data/timeFile_20230904_1513.csv')
# Read the response_csv and time_csv into DataFrames
response_df = pd.read_csv('./data/processed/merged_response.csv')
time_df = pd.read_csv('./data/processed/merged_time.csv')

# Remove spaces from column names in response_df
response_df.columns = response_df.columns.str.strip()

# Remove spaces from column names in time_df
time_df.columns = time_df.columns.str.strip()
# Remove spaces from column values in response_df
response_df = response_df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# Remove spaces from column values in time_df
time_df = time_df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# Specify the time_window in milliseconds
time_window = 5000  # Adjust this value as needed

# Function to calculate statistics within the time_window
def calculate_statistics(row):
    start_time = row['Elapsed Time (ms)'] - time_window
    relevant_data = time_df[(time_df['Elapsed Time (ms)'] >= start_time) & (time_df['Elapsed Time (ms)'] <= row['Elapsed Time (ms)'])]
    pitch_values = relevant_data['Pitch'].round().astype(int)
    yaw_values = relevant_data['Yaw'].round().astype(int)
    roll_values = relevant_data['Roll'].round().astype(int)

    std_pitch = pitch_values.std()
    var_pitch = pitch_values.var()
    mean_pitch = pitch_values.mean()
    mode_pitch = mode(pitch_values, axis=None)[0][0]
    median_pitch = pitch_values.median()

    std_yaw = yaw_values.std()
    var_yaw = yaw_values.var()
    mean_yaw = yaw_values.mean()
    mode_yaw = mode(yaw_values, axis=None)[0][0]
    median_yaw = yaw_values.median()

    std_roll = roll_values.std()
    var_roll = roll_values.var()
    mean_roll = roll_values.mean()
    mode_roll = mode(roll_values, axis=None)[0][0]
    median_roll = roll_values.median()

    return pd.Series({
        'std_pitch': round(std_pitch, 2),
        'var_pitch': round(var_pitch, 2),
        'mean_pitch': round(mean_pitch, 2),
        'mode_pitch': round(mode_pitch,2),   # Assuming this will always be a whole number
        'median_pitch': round(median_pitch, 2),
        'std_yaw': round(std_yaw, 2),
        'var_yaw': round(var_yaw, 2),
        'mean_yaw': round(mean_yaw, 2),
        'mode_yaw': round(mode_yaw,2),       # Assuming this will always be a whole number
        'median_yaw': round(median_yaw, 2),
        'std_roll': round(std_roll, 2),
        'var_roll': round(var_roll, 2),
        'mean_roll': round(mean_roll, 2),
        'mode_roll': round(mode_roll,2),     # Assuming this will always be a whole number
        'median_roll': round(median_roll, 2)
    })

# Convert 'Pitch', 'Yaw', and 'Roll' to integers in response_df and time_df
response_df['Pitch'] = response_df['Pitch'].round().astype(int)
response_df['Yaw'] = response_df['Yaw'].round().astype(int)
response_df['Roll'] = response_df['Roll'].round().astype(int)

time_df['Pitch'] = time_df['Pitch'].round().astype(int)
time_df['Yaw'] = time_df['Yaw'].round().astype(int)
time_df['Roll'] = time_df['Roll'].round().astype(int)

# Apply the function to each row in the response DataFrame
statistics_df = response_df.apply(calculate_statistics, axis=1)
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# ...
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:33: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_pitch = mode(pitch_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:39: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_yaw = mode(yaw_values, axis=None)[0][0]
# C:\Users\muham\AppData\Local\Temp\ipykernel_8656\267901704.py:45: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_roll = mode(roll_values, axis=None)[0][0]

# %%
# Concatenate the statistics DataFrame with the response DataFrame
merged_df = pd.concat([response_df, statistics_df], axis=1)

# Create the 'attentive' column
merged_df['Attentive'] = response_df['Correct'].apply(lambda x: 0 if x == 'No' else 1)

# Save the final DataFrame to a new CSV file
merged_df.to_csv('./data/processed/responseFile_with_statistics.csv', index=False, float_format='%.2f')

# %% [markdown]
# ### HeatMap

# %%
# Read the DataFrame
merged_df = pd.read_csv('./data/processed/responseFile_with_statistics.csv')

# Filter out only the columns of interest
selected_columns = merged_df.select_dtypes(include=['int64', 'float64'])
# Compute the correlation matrix for these columns
selected_columns = merged_df[['Yaw', 'mean_yaw', 'mode_yaw', 'Roll', 'var_pitch', 'mean_roll','mode_roll', 'median_roll' , 'Attentive']]
            
correlation_matrix_selected = selected_columns.corr()

# Create a mask for the upper triangle
mask = np.triu(np.ones_like(correlation_matrix_selected, dtype=bool))

# Create a heatmap using Seaborn
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix_selected, mask=mask, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Read the DataFrame
merged_df = pd.read_csv('./data/processed/responseFile_with_statistics.csv')

# Filter out only the columns of interest
selected_columns = merged_df.select_dtypes(include=['int64', 'float64'])
# Compute the correlation matrix for these columns
selected_columns = merged_df[['Yaw', 'mean_yaw', 'mode_yaw', 'Roll', 'var_pitch', 'mean_roll','mode_roll', 'median_roll' , 'Attentive']]
            
correlation_matrix_selected = selected_columns.corr()

# Create a mask for the upper triangle
mask = np.triu(np.ones_like(correlation_matrix_selected, dtype=bool))

# Create a heatmap using Seaborn
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix_selected, mask=mask, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### Reduce number of positive classes

# %%
# Read the CSV into a DataFrame
df = pd.read_csv('./data/processed/responseFile_with_statistics.csv')

# Filter rows where Attentive = 1 and shuffle
attentive_rows = df[df['Attentive'] == 1].sample(frac=1, random_state=42)

# Filter rows where Attentive != 1
non_attentive_rows = df[df['Attentive'] != 1]

# Concatenate the DataFrames
final_df = pd.concat([attentive_rows, non_attentive_rows], axis=0).sort_index()

# Save the final DataFrame to a new CSV file
final_df.to_csv('./data/processed/modified_responseFile_with_statistics.csv', index=False)

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Read your preprocessed DataFrame (responseFile_with_statistics.csv)
df = pd.read_csv('./data/processed/modified_responseFile_with_statistics.csv')

# Select the features and the target variable
features = df[['Yaw', 'std_yaw', 'mean_yaw', 'mode_yaw', 'median_yaw']]
target = df['Attentive']

# Select only the rows where the target variable is 0 or 1
target = target[target.isin([0, 1])]

# Split the data into a training and testing set
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Baseline model: Predict 1 if Yaw is between 150 and 200, else predict 0
y_pred_baseline = (X_test['Yaw'] >= 150) & (X_test['Yaw'] <= 200)
y_pred_baseline = y_pred_baseline.astype(int)  # Convert boolean values to integers

# Evaluate the baseline model
accuracy_baseline = accuracy_score(y_test, y_pred_baseline)
confusion_baseline = confusion_matrix(y_test, y_pred_baseline)
report_baseline = classification_report(y_test, y_pred_baseline)

print(f'Baseline Accuracy: {accuracy_baseline}')
print('Baseline Confusion Matrix:')
print(confusion_baseline)
print('Baseline Classification Report:')
print(report_baseline)

plt.figure(figsize=(8, 6))
sns.heatmap(confusion_baseline, annot=True, fmt='g', cmap='Blues', cbar=False, annot_kws={"size": 16}, xticklabels=['Not Attentive', 'Attentive'], yticklabels=['Not Attentive', 'Attentive'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Baseline Confusion Matrix')
plt.show()
# Out:
# Baseline Accuracy: 0.8525345622119815
# Baseline Confusion Matrix:
# [[ 11  18]
#  [ 14 174]]
# Baseline Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.44      0.38      0.41        29
#            1       0.91      0.93      0.92       188
#
#     accuracy                           0.85       217
#    macro avg       0.67      0.65      0.66       217
# weighted avg       0.84      0.85      0.85       217

# %% [markdown]
# ## Train-Test split

# %%
# Read your preproces
df = pd.read_csv('./data/processed/responseFile_with_statistics.csv')

# Select the features and the target variable
features = df[[
    'Yaw',
    'Pitch',
    'Roll',
    'std_pitch',
    'var_pitch',
    'mean_pitch',
    'median_pitch',
    'std_yaw',
    'var_yaw',
    'mean_yaw',
    'median_yaw',
    'std_roll',
    'var_roll',
    'mean_roll',
    'median_roll'
    ]]

# target class
y = df['Attentive']

# Scale the data
sc = StandardScaler()
features_scaled = sc.fit_transform(features)

# Split the data into a training and testing set
X_train, X_test, y_train, y_test = train_test_split(features_scaled, y, stratify=y, test_size=0.2, random_state=42)

# %% [markdown]
# ## SVM

# %%
# Create and train the Support Vector Machine (SVM) model
svm = SVC(kernel='linear')  # You can choose different kernels (linear, radial basis function, etc.)
svm.fit(X_train, y_train)

# Make predictions on the test set
y_pred = svm.predict(X_test)

# Evaluate the model
score = f1_score(y_test, y_pred, average='weighted')
print(f'F1 score for test data: {score*100:.2f}%')
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print('Confusion Matrix:')
print(confusion)
print('Classification Report:')
print(report)

plt.figure(figsize=(8, 6))
sns.heatmap(confusion, annot=True, fmt='g', cmap='Blues', cbar=False, annot_kws={"size": 16}, xticklabels=['Not Attentive', 'Attentive'], yticklabels=['Not Attentive', 'Attentive'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix for SVM Model on test set') 
plt.show()
# Out:
# F1 score for test data: 88.38%
# Accuracy: 0.8986175115207373
# Confusion Matrix:
# [[ 13  19]
#  [  3 182]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.41      0.54        32
#            1       0.91      0.98      0.94       185
#
#     accuracy                           0.90       217
#    macro avg       0.86      0.70      0.74       217
# weighted avg       0.89      0.90      0.88       217

# %%
# Make predictions on the test set
y_pred = svm.predict(X_train)

# Evaluate the model
accuracy = accuracy_score(y_train, y_pred)
confusion = confusion_matrix(y_train, y_pred)
report = classification_report(y_train, y_pred)

score = f1_score(y_train, y_pred, average='weighted')
print(f'F1 score for test data: {score*100:.2f}%')
print(f'Accuracy: {accuracy}')
print('Confusion Matrix:')
print(confusion)
print('Classification Report:')
print(report)

plt.figure(figsize=(8, 6))
sns.heatmap(confusion, annot=True, fmt='g', cmap='Blues', cbar=False, annot_kws={"size": 16}, xticklabels=['Not Attentive', 'Attentive'], yticklabels=['Not Attentive', 'Attentive'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix for SVM Model on train set')
plt.show()
# Out:
# F1 score for test data: 89.95%
# Accuracy: 0.9087759815242494
# Confusion Matrix:
# [[ 65  64]
#  [ 15 722]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.50      0.62       129
#            1       0.92      0.98      0.95       737
#
#     accuracy                           0.91       866
#    macro avg       0.87      0.74      0.79       866
# weighted avg       0.90      0.91      0.90       866

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train, y_train)

y_pred = rf_classifier.predict(X_train)
# Evaluate the model
accuracy = accuracy_score(y_train, y_pred)
confusion = confusion_matrix(y_train, y_pred)
report = classification_report(y_train, y_pred)

score = f1_score(y_train, y_pred, average='weighted')
print(f'F1 score for train data: {score*100:.2f}%')
print(f'Accuracy: {accuracy}')
print('Confusion Matrix:')
print(confusion)
print('Classification Report:')
print(report)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion, annot=True, fmt='g', cmap='Blues', cbar=False, annot_kws={"size": 16}, xticklabels=['Not Attentive', 'Attentive'], yticklabels=['Not Attentive', 'Attentive'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix for Random Forest Model on train set')
plt.show()
# Out:
# F1 score for train data: 98.30%
# Accuracy: 0.9826789838337182
# Confusion Matrix:
# [[128   1]
#  [ 14 723]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94       129
#            1       1.00      0.98      0.99       737
#
#     accuracy                           0.98       866
#    macro avg       0.95      0.99      0.97       866
# weighted avg       0.98      0.98      0.98       866

# %%
# Make predictions on the test set
y_pred = rf_classifier.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

score = f1_score(y_test, y_pred, average='weighted')
print(f'F1 score for test data: {score*100:.2f}%')
print(f'Accuracy: {accuracy}')
print('Confusion Matrix:')
print(confusion)
print('Classification Report:')
print(report)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion, annot=True, fmt='g', cmap='Blues', cbar=False, annot_kws={"size": 16}, xticklabels=['Not Attentive', 'Attentive'], yticklabels=['Not Attentive', 'Attentive'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix for Random Forest Model on test set')
plt.show()
# Out:
# F1 score for test data: 86.31%
# Accuracy: 0.8709677419354839
# Confusion Matrix:
# [[ 14  18]
#  [ 10 175]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.58      0.44      0.50        32
#            1       0.91      0.95      0.93       185
#
#     accuracy                           0.87       217
#    macro avg       0.75      0.69      0.71       217
# weighted avg       0.86      0.87      0.86       217

# %%
# save random forest model
import joblib
joblib.dump(rf_classifier, './models/discrete_random_forest_model.pkl')
# Out:
# ['./models/discrete_random_forest_model.pkl']

# %% [markdown]
# ## Neural Network

# %%
# Define the ANN model
model = Sequential([
    Dense(1024, activation='relu', input_shape=(features.shape[1],)),
    Dropout(0.7),
    Dense(32, activation='relu'),
    Dropout(0.7),
    Dense(8, activation='relu'),
    Dropout(0.25), 
    Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1024)              16384
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 32)                32800
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 8)                 264
#
#  dropout_2 (Dropout)         (None, 8)                 0
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 49457 (193.19 KB)
# Trainable params: 49457 (193.19 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
lr = 0.0001
optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
model.compile(optimizer=optimizer, loss=tf.keras.losses.MeanSquaredLogarithmicError(), metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=300, batch_size=32, validation_data=(X_test, y_test), class_weight={0: 3, 1: 1})
# Out:
# Epoch 1/300
# 28/28 [==============================] - 1s 8ms/step - loss: 0.1373 - accuracy: 0.4215 - val_loss: 0.0936 - val_accuracy: 0.6406
# Epoch 2/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1349 - accuracy: 0.4850 - val_loss: 0.0919 - val_accuracy: 0.7005
# Epoch 3/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1367 - accuracy: 0.5335 - val_loss: 0.0904 - val_accuracy: 0.7788
# Epoch 4/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1274 - accuracy: 0.5820 - val_loss: 0.0895 - val_accuracy: 0.8111
# Epoch 5/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1268 - accuracy: 0.6120 - val_loss: 0.0883 - val_accuracy: 0.8571
# Epoch 6/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1270 - accuracy: 0.6132 - val_loss: 0.0869 - val_accuracy: 0.8618
# Epoch 7/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1246 - accuracy: 0.6605 - val_loss: 0.0857 - val_accuracy: 0.8618
# Epoch 8/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1220 - accuracy: 0.6767 - val_loss: 0.0842 - val_accuracy: 0.8664
# Epoch 9/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1264 - accuracy: 0.6778 - val_loss: 0.0827 - val_accuracy: 0.8802
# Epoch 10/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.1254 - accuracy: 0.7067 - val_loss: 0.0813 - val_accuracy: 0.8848
# Epoch 11/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1232 - accuracy: 0.7333 - val_loss: 0.0805 - val_accuracy: 0.8802
# Epoch 12/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1182 - accuracy: 0.7436 - val_loss: 0.0792 - val_accuracy: 0.8848
# Epoch 13/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.1180 - accuracy: 0.7436 - val_loss: 0.0780 - val_accuracy: 0.8894
# Epoch 14/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1130 - accuracy: 0.7436 - val_loss: 0.0766 - val_accuracy: 0.8848
# Epoch 15/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1116 - accuracy: 0.7598 - val_loss: 0.0754 - val_accuracy: 0.8848
# Epoch 16/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1143 - accuracy: 0.7436 - val_loss: 0.0745 - val_accuracy: 0.8848
# Epoch 17/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1129 - accuracy: 0.7725 - val_loss: 0.0735 - val_accuracy: 0.8894
# Epoch 18/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.1052 - accuracy: 0.7633 - val_loss: 0.0726 - val_accuracy: 0.8894
# Epoch 19/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1083 - accuracy: 0.8095 - val_loss: 0.0711 - val_accuracy: 0.8940
# Epoch 20/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.1085 - accuracy: 0.7933 - val_loss: 0.0701 - val_accuracy: 0.8940
# Epoch 21/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1084 - accuracy: 0.7783 - val_loss: 0.0692 - val_accuracy: 0.8940
# Epoch 22/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1075 - accuracy: 0.7991 - val_loss: 0.0680 - val_accuracy: 0.8986
# Epoch 23/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1079 - accuracy: 0.8176 - val_loss: 0.0667 - val_accuracy: 0.8986
# Epoch 24/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1089 - accuracy: 0.8048 - val_loss: 0.0659 - val_accuracy: 0.8986
# Epoch 25/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1027 - accuracy: 0.8048 - val_loss: 0.0654 - val_accuracy: 0.8986
# Epoch 26/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1039 - accuracy: 0.8072 - val_loss: 0.0646 - val_accuracy: 0.9032
# Epoch 27/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.1074 - accuracy: 0.8083 - val_loss: 0.0644 - val_accuracy: 0.8986
# Epoch 28/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.1048 - accuracy: 0.8360 - val_loss: 0.0642 - val_accuracy: 0.8986
# Epoch 29/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1006 - accuracy: 0.8349 - val_loss: 0.0633 - val_accuracy: 0.8986
# Epoch 30/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1056 - accuracy: 0.8176 - val_loss: 0.0626 - val_accuracy: 0.8986
# Epoch 31/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1049 - accuracy: 0.8268 - val_loss: 0.0622 - val_accuracy: 0.8986
# Epoch 32/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1041 - accuracy: 0.8268 - val_loss: 0.0620 - val_accuracy: 0.8986
# Epoch 33/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0999 - accuracy: 0.8383 - val_loss: 0.0612 - val_accuracy: 0.8986
# Epoch 34/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1009 - accuracy: 0.8187 - val_loss: 0.0602 - val_accuracy: 0.8986
# Epoch 35/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1009 - accuracy: 0.8372 - val_loss: 0.0594 - val_accuracy: 0.8986
# Epoch 36/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0983 - accuracy: 0.8233 - val_loss: 0.0591 - val_accuracy: 0.8986
# Epoch 37/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0987 - accuracy: 0.8418 - val_loss: 0.0585 - val_accuracy: 0.8986
# Epoch 38/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1014 - accuracy: 0.8303 - val_loss: 0.0578 - val_accuracy: 0.8986
# Epoch 39/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0957 - accuracy: 0.8476 - val_loss: 0.0577 - val_accuracy: 0.8986
# Epoch 40/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0952 - accuracy: 0.8337 - val_loss: 0.0569 - val_accuracy: 0.8986
# Epoch 41/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0979 - accuracy: 0.8557 - val_loss: 0.0564 - val_accuracy: 0.8940
# Epoch 42/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0999 - accuracy: 0.8326 - val_loss: 0.0561 - val_accuracy: 0.8986
# Epoch 43/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1000 - accuracy: 0.8418 - val_loss: 0.0557 - val_accuracy: 0.8986
# Epoch 44/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0988 - accuracy: 0.8522 - val_loss: 0.0555 - val_accuracy: 0.8986
# Epoch 45/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1026 - accuracy: 0.8372 - val_loss: 0.0555 - val_accuracy: 0.8894
# Epoch 46/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0987 - accuracy: 0.8522 - val_loss: 0.0552 - val_accuracy: 0.8894
# Epoch 47/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0975 - accuracy: 0.8383 - val_loss: 0.0551 - val_accuracy: 0.8894
# Epoch 48/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0964 - accuracy: 0.8603 - val_loss: 0.0548 - val_accuracy: 0.8894
# Epoch 49/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0952 - accuracy: 0.8395 - val_loss: 0.0546 - val_accuracy: 0.8894
# Epoch 50/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0940 - accuracy: 0.8545 - val_loss: 0.0543 - val_accuracy: 0.8894
# Epoch 51/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0955 - accuracy: 0.8499 - val_loss: 0.0542 - val_accuracy: 0.8894
# Epoch 52/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0953 - accuracy: 0.8453 - val_loss: 0.0540 - val_accuracy: 0.8894
# Epoch 53/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0973 - accuracy: 0.8533 - val_loss: 0.0539 - val_accuracy: 0.8940
# Epoch 54/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0899 - accuracy: 0.8614 - val_loss: 0.0536 - val_accuracy: 0.8940
# Epoch 55/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0931 - accuracy: 0.8626 - val_loss: 0.0531 - val_accuracy: 0.8940
# Epoch 56/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0957 - accuracy: 0.8568 - val_loss: 0.0527 - val_accuracy: 0.8940
# Epoch 57/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0892 - accuracy: 0.8672 - val_loss: 0.0524 - val_accuracy: 0.8940
# Epoch 58/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0985 - accuracy: 0.8441 - val_loss: 0.0520 - val_accuracy: 0.8940
# Epoch 59/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0909 - accuracy: 0.8684 - val_loss: 0.0518 - val_accuracy: 0.8940
# Epoch 60/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0919 - accuracy: 0.8672 - val_loss: 0.0517 - val_accuracy: 0.8940
# Epoch 61/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0942 - accuracy: 0.8545 - val_loss: 0.0517 - val_accuracy: 0.8940
# Epoch 62/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0954 - accuracy: 0.8649 - val_loss: 0.0515 - val_accuracy: 0.8940
# Epoch 63/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0901 - accuracy: 0.8741 - val_loss: 0.0513 - val_accuracy: 0.8940
# Epoch 64/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0898 - accuracy: 0.8695 - val_loss: 0.0511 - val_accuracy: 0.8940
# Epoch 65/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0957 - accuracy: 0.8695 - val_loss: 0.0509 - val_accuracy: 0.8940
# Epoch 66/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0926 - accuracy: 0.8580 - val_loss: 0.0506 - val_accuracy: 0.8940
# Epoch 67/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0922 - accuracy: 0.8649 - val_loss: 0.0507 - val_accuracy: 0.8940
# Epoch 68/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0884 - accuracy: 0.8707 - val_loss: 0.0503 - val_accuracy: 0.8940
# Epoch 69/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0870 - accuracy: 0.8707 - val_loss: 0.0505 - val_accuracy: 0.8940
# Epoch 70/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0904 - accuracy: 0.8637 - val_loss: 0.0503 - val_accuracy: 0.8940
# Epoch 71/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0943 - accuracy: 0.8672 - val_loss: 0.0502 - val_accuracy: 0.8940
# Epoch 72/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0921 - accuracy: 0.8764 - val_loss: 0.0500 - val_accuracy: 0.8940
# Epoch 73/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0893 - accuracy: 0.8730 - val_loss: 0.0500 - val_accuracy: 0.8940
# Epoch 74/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0918 - accuracy: 0.8649 - val_loss: 0.0499 - val_accuracy: 0.8940
# Epoch 75/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0891 - accuracy: 0.8614 - val_loss: 0.0498 - val_accuracy: 0.8940
# Epoch 76/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0885 - accuracy: 0.8661 - val_loss: 0.0496 - val_accuracy: 0.8940
# Epoch 77/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0860 - accuracy: 0.8730 - val_loss: 0.0496 - val_accuracy: 0.8940
# Epoch 78/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0904 - accuracy: 0.8741 - val_loss: 0.0500 - val_accuracy: 0.8940
# Epoch 79/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0942 - accuracy: 0.8557 - val_loss: 0.0499 - val_accuracy: 0.8894
# Epoch 80/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0920 - accuracy: 0.8626 - val_loss: 0.0498 - val_accuracy: 0.8848
# Epoch 81/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0941 - accuracy: 0.8603 - val_loss: 0.0497 - val_accuracy: 0.8940
# Epoch 82/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0883 - accuracy: 0.8626 - val_loss: 0.0496 - val_accuracy: 0.8940
# Epoch 83/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0879 - accuracy: 0.8753 - val_loss: 0.0494 - val_accuracy: 0.8940
# Epoch 84/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0910 - accuracy: 0.8857 - val_loss: 0.0493 - val_accuracy: 0.8940
# Epoch 85/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0892 - accuracy: 0.8753 - val_loss: 0.0491 - val_accuracy: 0.8940
# Epoch 86/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0864 - accuracy: 0.8649 - val_loss: 0.0490 - val_accuracy: 0.8940
# Epoch 87/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0870 - accuracy: 0.8684 - val_loss: 0.0489 - val_accuracy: 0.8986
# Epoch 88/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0910 - accuracy: 0.8776 - val_loss: 0.0490 - val_accuracy: 0.8894
# Epoch 89/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0860 - accuracy: 0.8649 - val_loss: 0.0489 - val_accuracy: 0.8986
# Epoch 90/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0888 - accuracy: 0.8764 - val_loss: 0.0489 - val_accuracy: 0.8940
# Epoch 91/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0873 - accuracy: 0.8741 - val_loss: 0.0487 - val_accuracy: 0.8940
# Epoch 92/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0838 - accuracy: 0.8718 - val_loss: 0.0486 - val_accuracy: 0.8940
# Epoch 93/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0868 - accuracy: 0.8799 - val_loss: 0.0485 - val_accuracy: 0.8894
# Epoch 94/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0870 - accuracy: 0.8822 - val_loss: 0.0482 - val_accuracy: 0.8894
# Epoch 95/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0868 - accuracy: 0.8637 - val_loss: 0.0482 - val_accuracy: 0.8894
# Epoch 96/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0917 - accuracy: 0.8776 - val_loss: 0.0481 - val_accuracy: 0.8848
# Epoch 97/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0880 - accuracy: 0.8845 - val_loss: 0.0483 - val_accuracy: 0.8848
# Epoch 98/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0837 - accuracy: 0.8764 - val_loss: 0.0482 - val_accuracy: 0.8894
# Epoch 99/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0863 - accuracy: 0.8857 - val_loss: 0.0480 - val_accuracy: 0.8848
# Epoch 100/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0869 - accuracy: 0.8764 - val_loss: 0.0479 - val_accuracy: 0.8848
# Epoch 101/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0900 - accuracy: 0.8764 - val_loss: 0.0479 - val_accuracy: 0.8848
# Epoch 102/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0852 - accuracy: 0.8788 - val_loss: 0.0477 - val_accuracy: 0.8802
# Epoch 103/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0822 - accuracy: 0.8741 - val_loss: 0.0477 - val_accuracy: 0.8756
# Epoch 104/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0927 - accuracy: 0.8649 - val_loss: 0.0476 - val_accuracy: 0.8756
# Epoch 105/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0848 - accuracy: 0.8788 - val_loss: 0.0476 - val_accuracy: 0.8802
# Epoch 106/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0852 - accuracy: 0.8730 - val_loss: 0.0476 - val_accuracy: 0.8802
# Epoch 107/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0876 - accuracy: 0.8776 - val_loss: 0.0476 - val_accuracy: 0.8802
# Epoch 108/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0845 - accuracy: 0.8718 - val_loss: 0.0474 - val_accuracy: 0.8802
# Epoch 109/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0860 - accuracy: 0.8857 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 110/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0855 - accuracy: 0.8753 - val_loss: 0.0475 - val_accuracy: 0.8756
# Epoch 111/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0841 - accuracy: 0.8672 - val_loss: 0.0476 - val_accuracy: 0.8756
# Epoch 112/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0868 - accuracy: 0.8822 - val_loss: 0.0474 - val_accuracy: 0.8710
# Epoch 113/300
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0863 - accuracy: 0.8834 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 114/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0890 - accuracy: 0.8684 - val_loss: 0.0475 - val_accuracy: 0.8710
# Epoch 115/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0854 - accuracy: 0.8799 - val_loss: 0.0476 - val_accuracy: 0.8710
# Epoch 116/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0831 - accuracy: 0.8799 - val_loss: 0.0475 - val_accuracy: 0.8710
# Epoch 117/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0828 - accuracy: 0.8868 - val_loss: 0.0475 - val_accuracy: 0.8710
# Epoch 118/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0877 - accuracy: 0.8811 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 119/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0928 - accuracy: 0.8568 - val_loss: 0.0474 - val_accuracy: 0.8756
# Epoch 120/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0824 - accuracy: 0.8938 - val_loss: 0.0476 - val_accuracy: 0.8710
# Epoch 121/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0827 - accuracy: 0.8788 - val_loss: 0.0475 - val_accuracy: 0.8710
# Epoch 122/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0822 - accuracy: 0.8926 - val_loss: 0.0475 - val_accuracy: 0.8710
# Epoch 123/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0861 - accuracy: 0.8764 - val_loss: 0.0472 - val_accuracy: 0.8756
# Epoch 124/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0815 - accuracy: 0.8915 - val_loss: 0.0472 - val_accuracy: 0.8710
# Epoch 125/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0836 - accuracy: 0.8799 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 126/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0804 - accuracy: 0.8741 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 127/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0847 - accuracy: 0.8764 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 128/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0818 - accuracy: 0.8834 - val_loss: 0.0475 - val_accuracy: 0.8710
# Epoch 129/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0846 - accuracy: 0.8868 - val_loss: 0.0475 - val_accuracy: 0.8710
# Epoch 130/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0829 - accuracy: 0.8868 - val_loss: 0.0474 - val_accuracy: 0.8710
# Epoch 131/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0849 - accuracy: 0.8776 - val_loss: 0.0472 - val_accuracy: 0.8710
# Epoch 132/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0802 - accuracy: 0.8915 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 133/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0844 - accuracy: 0.8788 - val_loss: 0.0472 - val_accuracy: 0.8710
# Epoch 134/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0839 - accuracy: 0.8857 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 135/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0880 - accuracy: 0.8822 - val_loss: 0.0474 - val_accuracy: 0.8710
# Epoch 136/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0810 - accuracy: 0.8845 - val_loss: 0.0474 - val_accuracy: 0.8710
# Epoch 137/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0906 - accuracy: 0.8776 - val_loss: 0.0475 - val_accuracy: 0.8710
# Epoch 138/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0870 - accuracy: 0.8741 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 139/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0844 - accuracy: 0.8822 - val_loss: 0.0471 - val_accuracy: 0.8710
# Epoch 140/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0849 - accuracy: 0.8776 - val_loss: 0.0472 - val_accuracy: 0.8710
# Epoch 141/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0814 - accuracy: 0.8880 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 142/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0818 - accuracy: 0.8799 - val_loss: 0.0471 - val_accuracy: 0.8710
# Epoch 143/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0769 - accuracy: 0.8799 - val_loss: 0.0470 - val_accuracy: 0.8710
# Epoch 144/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0842 - accuracy: 0.8730 - val_loss: 0.0470 - val_accuracy: 0.8710
# Epoch 145/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0807 - accuracy: 0.8891 - val_loss: 0.0470 - val_accuracy: 0.8756
# Epoch 146/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0788 - accuracy: 0.8799 - val_loss: 0.0471 - val_accuracy: 0.8710
# Epoch 147/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0871 - accuracy: 0.8753 - val_loss: 0.0472 - val_accuracy: 0.8756
# Epoch 148/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0836 - accuracy: 0.8880 - val_loss: 0.0472 - val_accuracy: 0.8710
# Epoch 149/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0840 - accuracy: 0.8822 - val_loss: 0.0471 - val_accuracy: 0.8710
# Epoch 150/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0828 - accuracy: 0.8880 - val_loss: 0.0470 - val_accuracy: 0.8710
# Epoch 151/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0880 - accuracy: 0.8776 - val_loss: 0.0471 - val_accuracy: 0.8710
# Epoch 152/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0893 - accuracy: 0.8788 - val_loss: 0.0474 - val_accuracy: 0.8710
# Epoch 153/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0829 - accuracy: 0.8880 - val_loss: 0.0474 - val_accuracy: 0.8710
# Epoch 154/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0812 - accuracy: 0.8857 - val_loss: 0.0475 - val_accuracy: 0.8756
# Epoch 155/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0833 - accuracy: 0.8868 - val_loss: 0.0475 - val_accuracy: 0.8756
# Epoch 156/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0847 - accuracy: 0.8822 - val_loss: 0.0474 - val_accuracy: 0.8756
# Epoch 157/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0854 - accuracy: 0.8776 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 158/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0825 - accuracy: 0.8915 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 159/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0823 - accuracy: 0.8776 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 160/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0820 - accuracy: 0.8845 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 161/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0803 - accuracy: 0.8949 - val_loss: 0.0474 - val_accuracy: 0.8710
# Epoch 162/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0823 - accuracy: 0.8845 - val_loss: 0.0475 - val_accuracy: 0.8756
# Epoch 163/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0830 - accuracy: 0.8718 - val_loss: 0.0474 - val_accuracy: 0.8710
# Epoch 164/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0824 - accuracy: 0.8845 - val_loss: 0.0477 - val_accuracy: 0.8756
# Epoch 165/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0845 - accuracy: 0.8811 - val_loss: 0.0476 - val_accuracy: 0.8710
# Epoch 166/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0776 - accuracy: 0.8880 - val_loss: 0.0476 - val_accuracy: 0.8710
# Epoch 167/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0805 - accuracy: 0.8903 - val_loss: 0.0476 - val_accuracy: 0.8710
# Epoch 168/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0834 - accuracy: 0.8845 - val_loss: 0.0475 - val_accuracy: 0.8710
# Epoch 169/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0863 - accuracy: 0.8811 - val_loss: 0.0475 - val_accuracy: 0.8710
# Epoch 170/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0801 - accuracy: 0.8764 - val_loss: 0.0477 - val_accuracy: 0.8710
# Epoch 171/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0834 - accuracy: 0.8845 - val_loss: 0.0477 - val_accuracy: 0.8710
# Epoch 172/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0777 - accuracy: 0.8857 - val_loss: 0.0476 - val_accuracy: 0.8710
# Epoch 173/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0854 - accuracy: 0.8695 - val_loss: 0.0476 - val_accuracy: 0.8710
# Epoch 174/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0843 - accuracy: 0.8730 - val_loss: 0.0475 - val_accuracy: 0.8710
# Epoch 175/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0821 - accuracy: 0.8868 - val_loss: 0.0475 - val_accuracy: 0.8710
# Epoch 176/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0814 - accuracy: 0.8799 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 177/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0816 - accuracy: 0.8972 - val_loss: 0.0474 - val_accuracy: 0.8710
# Epoch 178/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0834 - accuracy: 0.8915 - val_loss: 0.0475 - val_accuracy: 0.8710
# Epoch 179/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0831 - accuracy: 0.8868 - val_loss: 0.0476 - val_accuracy: 0.8710
# Epoch 180/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0823 - accuracy: 0.8776 - val_loss: 0.0476 - val_accuracy: 0.8710
# Epoch 181/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0805 - accuracy: 0.8926 - val_loss: 0.0477 - val_accuracy: 0.8756
# Epoch 182/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0814 - accuracy: 0.8730 - val_loss: 0.0474 - val_accuracy: 0.8710
# Epoch 183/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0805 - accuracy: 0.8799 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 184/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0789 - accuracy: 0.8845 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 185/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0858 - accuracy: 0.8926 - val_loss: 0.0470 - val_accuracy: 0.8710
# Epoch 186/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0830 - accuracy: 0.8811 - val_loss: 0.0470 - val_accuracy: 0.8710
# Epoch 187/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0796 - accuracy: 0.8868 - val_loss: 0.0471 - val_accuracy: 0.8710
# Epoch 188/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0812 - accuracy: 0.8926 - val_loss: 0.0471 - val_accuracy: 0.8710
# Epoch 189/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0826 - accuracy: 0.8845 - val_loss: 0.0471 - val_accuracy: 0.8710
# Epoch 190/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0727 - accuracy: 0.8995 - val_loss: 0.0470 - val_accuracy: 0.8710
# Epoch 191/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0847 - accuracy: 0.8880 - val_loss: 0.0469 - val_accuracy: 0.8710
# Epoch 192/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0836 - accuracy: 0.8776 - val_loss: 0.0469 - val_accuracy: 0.8710
# Epoch 193/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0822 - accuracy: 0.8926 - val_loss: 0.0470 - val_accuracy: 0.8710
# Epoch 194/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0828 - accuracy: 0.8857 - val_loss: 0.0471 - val_accuracy: 0.8710
# Epoch 195/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0813 - accuracy: 0.8903 - val_loss: 0.0470 - val_accuracy: 0.8710
# Epoch 196/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0827 - accuracy: 0.8799 - val_loss: 0.0469 - val_accuracy: 0.8710
# Epoch 197/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0862 - accuracy: 0.8811 - val_loss: 0.0472 - val_accuracy: 0.8710
# Epoch 198/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0791 - accuracy: 0.8961 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 199/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0795 - accuracy: 0.8972 - val_loss: 0.0472 - val_accuracy: 0.8756
# Epoch 200/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0814 - accuracy: 0.8845 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 201/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0749 - accuracy: 0.9007 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 202/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0799 - accuracy: 0.8903 - val_loss: 0.0475 - val_accuracy: 0.8710
# Epoch 203/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0822 - accuracy: 0.8834 - val_loss: 0.0474 - val_accuracy: 0.8710
# Epoch 204/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0839 - accuracy: 0.8880 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 205/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0783 - accuracy: 0.8995 - val_loss: 0.0474 - val_accuracy: 0.8710
# Epoch 206/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0768 - accuracy: 0.8868 - val_loss: 0.0474 - val_accuracy: 0.8710
# Epoch 207/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0811 - accuracy: 0.8891 - val_loss: 0.0476 - val_accuracy: 0.8710
# Epoch 208/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0797 - accuracy: 0.8903 - val_loss: 0.0475 - val_accuracy: 0.8710
# Epoch 209/300
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0871 - accuracy: 0.8868 - val_loss: 0.0474 - val_accuracy: 0.8710
# Epoch 210/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0793 - accuracy: 0.8868 - val_loss: 0.0474 - val_accuracy: 0.8710
# Epoch 211/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0776 - accuracy: 0.8949 - val_loss: 0.0475 - val_accuracy: 0.8710
# Epoch 212/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0767 - accuracy: 0.8949 - val_loss: 0.0476 - val_accuracy: 0.8710
# Epoch 213/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0817 - accuracy: 0.8938 - val_loss: 0.0478 - val_accuracy: 0.8710
# Epoch 214/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0788 - accuracy: 0.8949 - val_loss: 0.0478 - val_accuracy: 0.8710
# Epoch 215/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0820 - accuracy: 0.8880 - val_loss: 0.0477 - val_accuracy: 0.8710
# Epoch 216/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0788 - accuracy: 0.8938 - val_loss: 0.0476 - val_accuracy: 0.8710
# Epoch 217/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0782 - accuracy: 0.8972 - val_loss: 0.0475 - val_accuracy: 0.8710
# Epoch 218/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0826 - accuracy: 0.8822 - val_loss: 0.0474 - val_accuracy: 0.8710
# Epoch 219/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0793 - accuracy: 0.8857 - val_loss: 0.0477 - val_accuracy: 0.8710
# Epoch 220/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0795 - accuracy: 0.8799 - val_loss: 0.0478 - val_accuracy: 0.8710
# Epoch 221/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0779 - accuracy: 0.8949 - val_loss: 0.0480 - val_accuracy: 0.8710
# Epoch 222/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0803 - accuracy: 0.8811 - val_loss: 0.0481 - val_accuracy: 0.8710
# Epoch 223/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0815 - accuracy: 0.8822 - val_loss: 0.0478 - val_accuracy: 0.8710
# Epoch 224/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0807 - accuracy: 0.8822 - val_loss: 0.0479 - val_accuracy: 0.8710
# Epoch 225/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0777 - accuracy: 0.8822 - val_loss: 0.0476 - val_accuracy: 0.8756
# Epoch 226/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0789 - accuracy: 0.8822 - val_loss: 0.0476 - val_accuracy: 0.8710
# Epoch 227/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0834 - accuracy: 0.8764 - val_loss: 0.0475 - val_accuracy: 0.8756
# Epoch 228/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0792 - accuracy: 0.8972 - val_loss: 0.0474 - val_accuracy: 0.8756
# Epoch 229/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0753 - accuracy: 0.8949 - val_loss: 0.0475 - val_accuracy: 0.8710
# Epoch 230/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0831 - accuracy: 0.8868 - val_loss: 0.0476 - val_accuracy: 0.8710
# Epoch 231/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0823 - accuracy: 0.8938 - val_loss: 0.0475 - val_accuracy: 0.8710
# Epoch 232/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0759 - accuracy: 0.8949 - val_loss: 0.0476 - val_accuracy: 0.8710
# Epoch 233/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0762 - accuracy: 0.8868 - val_loss: 0.0473 - val_accuracy: 0.8756
# Epoch 234/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0784 - accuracy: 0.8938 - val_loss: 0.0472 - val_accuracy: 0.8756
# Epoch 235/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0745 - accuracy: 0.9030 - val_loss: 0.0472 - val_accuracy: 0.8756
# Epoch 236/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0811 - accuracy: 0.8995 - val_loss: 0.0471 - val_accuracy: 0.8756
# Epoch 237/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0777 - accuracy: 0.8961 - val_loss: 0.0471 - val_accuracy: 0.8756
# Epoch 238/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0771 - accuracy: 0.8949 - val_loss: 0.0473 - val_accuracy: 0.8756
# Epoch 239/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0835 - accuracy: 0.8822 - val_loss: 0.0473 - val_accuracy: 0.8710
# Epoch 240/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0792 - accuracy: 0.8857 - val_loss: 0.0472 - val_accuracy: 0.8756
# Epoch 241/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0803 - accuracy: 0.8891 - val_loss: 0.0473 - val_accuracy: 0.8756
# Epoch 242/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0793 - accuracy: 0.8938 - val_loss: 0.0473 - val_accuracy: 0.8756
# Epoch 243/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0768 - accuracy: 0.8938 - val_loss: 0.0474 - val_accuracy: 0.8756
# Epoch 244/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0769 - accuracy: 0.8868 - val_loss: 0.0474 - val_accuracy: 0.8756
# Epoch 245/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0790 - accuracy: 0.8949 - val_loss: 0.0474 - val_accuracy: 0.8756
# Epoch 246/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0818 - accuracy: 0.8845 - val_loss: 0.0474 - val_accuracy: 0.8756
# Epoch 247/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0793 - accuracy: 0.8961 - val_loss: 0.0476 - val_accuracy: 0.8664
# Epoch 248/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0771 - accuracy: 0.8834 - val_loss: 0.0478 - val_accuracy: 0.8664
# Epoch 249/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0821 - accuracy: 0.8834 - val_loss: 0.0480 - val_accuracy: 0.8664
# Epoch 250/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0779 - accuracy: 0.8938 - val_loss: 0.0479 - val_accuracy: 0.8664
# Epoch 251/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0762 - accuracy: 0.8949 - val_loss: 0.0479 - val_accuracy: 0.8664
# Epoch 252/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0762 - accuracy: 0.8926 - val_loss: 0.0480 - val_accuracy: 0.8664
# Epoch 253/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0820 - accuracy: 0.8949 - val_loss: 0.0479 - val_accuracy: 0.8710
# Epoch 254/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0742 - accuracy: 0.8938 - val_loss: 0.0478 - val_accuracy: 0.8710
# Epoch 255/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0787 - accuracy: 0.8995 - val_loss: 0.0481 - val_accuracy: 0.8664
# Epoch 256/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0785 - accuracy: 0.8995 - val_loss: 0.0482 - val_accuracy: 0.8664
# Epoch 257/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0797 - accuracy: 0.8880 - val_loss: 0.0482 - val_accuracy: 0.8710
# Epoch 258/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0784 - accuracy: 0.8845 - val_loss: 0.0483 - val_accuracy: 0.8664
# Epoch 259/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0784 - accuracy: 0.8938 - val_loss: 0.0481 - val_accuracy: 0.8710
# Epoch 260/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0747 - accuracy: 0.8915 - val_loss: 0.0479 - val_accuracy: 0.8710
# Epoch 261/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0781 - accuracy: 0.8903 - val_loss: 0.0480 - val_accuracy: 0.8710
# Epoch 262/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0795 - accuracy: 0.8949 - val_loss: 0.0481 - val_accuracy: 0.8710
# Epoch 263/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0778 - accuracy: 0.8961 - val_loss: 0.0481 - val_accuracy: 0.8710
# Epoch 264/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0848 - accuracy: 0.8915 - val_loss: 0.0479 - val_accuracy: 0.8710
# Epoch 265/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0789 - accuracy: 0.8845 - val_loss: 0.0478 - val_accuracy: 0.8710
# Epoch 266/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0775 - accuracy: 0.8915 - val_loss: 0.0477 - val_accuracy: 0.8710
# Epoch 267/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0770 - accuracy: 0.8984 - val_loss: 0.0480 - val_accuracy: 0.8710
# Epoch 268/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0756 - accuracy: 0.8926 - val_loss: 0.0480 - val_accuracy: 0.8710
# Epoch 269/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0801 - accuracy: 0.8845 - val_loss: 0.0478 - val_accuracy: 0.8710
# Epoch 270/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0743 - accuracy: 0.8857 - val_loss: 0.0477 - val_accuracy: 0.8710
# Epoch 271/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0797 - accuracy: 0.8972 - val_loss: 0.0474 - val_accuracy: 0.8710
# Epoch 272/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0826 - accuracy: 0.8857 - val_loss: 0.0476 - val_accuracy: 0.8710
# Epoch 273/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0739 - accuracy: 0.8984 - val_loss: 0.0477 - val_accuracy: 0.8710
# Epoch 274/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0772 - accuracy: 0.8915 - val_loss: 0.0476 - val_accuracy: 0.8710
# Epoch 275/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0770 - accuracy: 0.8949 - val_loss: 0.0475 - val_accuracy: 0.8710
# Epoch 276/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0770 - accuracy: 0.8984 - val_loss: 0.0476 - val_accuracy: 0.8710
# Epoch 277/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0772 - accuracy: 0.8949 - val_loss: 0.0479 - val_accuracy: 0.8710
# Epoch 278/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0716 - accuracy: 0.8984 - val_loss: 0.0480 - val_accuracy: 0.8710
# Epoch 279/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0768 - accuracy: 0.8972 - val_loss: 0.0480 - val_accuracy: 0.8710
# Epoch 280/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0805 - accuracy: 0.8915 - val_loss: 0.0478 - val_accuracy: 0.8710
# Epoch 281/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0808 - accuracy: 0.8926 - val_loss: 0.0478 - val_accuracy: 0.8710
# Epoch 282/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0757 - accuracy: 0.8938 - val_loss: 0.0481 - val_accuracy: 0.8710
# Epoch 283/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0779 - accuracy: 0.8938 - val_loss: 0.0478 - val_accuracy: 0.8710
# Epoch 284/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0713 - accuracy: 0.9018 - val_loss: 0.0479 - val_accuracy: 0.8710
# Epoch 285/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0757 - accuracy: 0.8799 - val_loss: 0.0481 - val_accuracy: 0.8710
# Epoch 286/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0756 - accuracy: 0.8926 - val_loss: 0.0479 - val_accuracy: 0.8710
# Epoch 287/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0797 - accuracy: 0.8868 - val_loss: 0.0476 - val_accuracy: 0.8710
# Epoch 288/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0761 - accuracy: 0.9007 - val_loss: 0.0477 - val_accuracy: 0.8710
# Epoch 289/300
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0776 - accuracy: 0.9018 - val_loss: 0.0480 - val_accuracy: 0.8710
# Epoch 290/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0737 - accuracy: 0.9065 - val_loss: 0.0482 - val_accuracy: 0.8710
# Epoch 291/300
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0800 - accuracy: 0.8845 - val_loss: 0.0483 - val_accuracy: 0.8710
# Epoch 292/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0754 - accuracy: 0.9007 - val_loss: 0.0485 - val_accuracy: 0.8664
# Epoch 293/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0766 - accuracy: 0.8880 - val_loss: 0.0483 - val_accuracy: 0.8710
# Epoch 294/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0753 - accuracy: 0.8949 - val_loss: 0.0482 - val_accuracy: 0.8710
# Epoch 295/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0767 - accuracy: 0.8891 - val_loss: 0.0482 - val_accuracy: 0.8710
# Epoch 296/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0751 - accuracy: 0.8868 - val_loss: 0.0481 - val_accuracy: 0.8710
# Epoch 297/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0734 - accuracy: 0.9042 - val_loss: 0.0481 - val_accuracy: 0.8710
# Epoch 298/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0782 - accuracy: 0.8891 - val_loss: 0.0481 - val_accuracy: 0.8710
# Epoch 299/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0775 - accuracy: 0.8961 - val_loss: 0.0481 - val_accuracy: 0.8710
# Epoch 300/300
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0735 - accuracy: 0.9007 - val_loss: 0.0481 - val_accuracy: 0.8710

# %%
# Plot accuracy and loss
fig, ax = plt.subplots(2, 1, figsize=(10,10))
ax[0].plot(history.history['accuracy'], label='Train Accuracy')
ax[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
ax[0].legend()
ax[0].set_title('Accuracy')

ax[1].plot(history.history['loss'], label='Train Loss')
ax[1].plot(history.history['val_loss'], label='Validation Loss')
ax[1].legend()
ax[1].set_title('Loss')

plt.tight_layout()
plt.show()

# %%
y_pred = (model.predict(X_test) > 0.5).astype(int)
# Generate the confusion matrix
confusion = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print('Classification Report:')
print(report)
 
# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion, annot=True, fmt='g', cmap='Blues', cbar=False, annot_kws={"size": 16}, xticklabels=['Not Attentive', 'Attentive'], yticklabels=['Not Attentive', 'Attentive'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix for Neural Network Model on test set')
plt.show()
# Out:
# 7/7 [==============================] - 0s 834us/step
# Accuracy: 0.8709677419354839
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56        32
#            1       0.92      0.92      0.92       185
#
#     accuracy                           0.87       217
#    macro avg       0.74      0.74      0.74       217
# weighted avg       0.87      0.87      0.87       217

# %%
score = f1_score(y_test, y_pred, average='weighted')
print(f'F1 score for test data: {score*100:.2f}%')
# Out:
# F1 score for test data: 87.10%

# %%
y_pred = (model.predict(X_train) > 0.5).astype(int)
# Generate the confusion matrix
confusion = confusion_matrix(y_train, y_pred)

report = classification_report(y_train, y_pred)

print(f'Accuracy: {accuracy}')
print('Classification Report:')
print(report)


# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion, annot=True, fmt='g', cmap='Blues', cbar=False, annot_kws={"size": 16}, xticklabels=['Not Attentive', 'Attentive'], yticklabels=['Not Attentive', 'Attentive'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix for Neural Network Model on train set')
plt.show()
# Out:
# 28/28 [==============================] - 0s 778us/step
# Accuracy: 0.8709677419354839
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.73      0.72       129
#            1       0.95      0.95      0.95       737
#
#     accuracy                           0.91       866
#    macro avg       0.83      0.84      0.83       866
# weighted avg       0.92      0.91      0.92       866

# %%
score = f1_score(y_train, y_pred, average='weighted')
print(f'F1 score for training data: {score*100:.2f}%')
# Out:
# F1 score for training data: 91.51%

# %%
# save nn model
model.save('./models/discrete_nn_model.h5')
# Out:
# c:\Users\muham\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
